# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/DSData/master/winequality-red.csv')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
# Firstly we'll do non graphical analysis

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
# We can observe that no null values are present in the dataframe ,so there's no need to fill blank values

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
# Every feature has continous data, as a result,no need of encoding
## There are no object values to be encoded into numerical values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
# In second step we'll be doing Graphical ananlysis

# %%
plt.title('Counts of qulity ratings ')
sns.countplot(x='quality',data=df)
plt.show()

# %%
## From the above plot we can observe that count of quality 5 and 6 is more as compared to other ratings which in turn creates classs imbalance ,Oversampling methods will help this

# %%
## Finding relations between different features and Labels and their impact on Quality

# %%
plt.title('Impact of fixed acidity on Quality')
sns.scatterplot(x='quality',y='fixed acidity',data=df)
plt.show()

# %%
##

# %%
plt.title('Impact of volatile acidity on quality')
sns.scatterplot(x='quality',hue='quality',data=df)
plt.show()

# %%
plt.title('Impact of citric acid  on quality')
sns.scatterplot(x='citric acid',y='quality',data=df)
plt.show()

# %% [markdown]
# ## EDA- Exploratory Data Analysis

# %%
df_correlation=df.corr()
df_correlation
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
plt.figure(figsize=(20,10))
plt.title('Interelationship among cells')
sns.heatmap(df_correlation,cmap='pink',annot=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
## Here boxes which are light in colour are highly corrrelated
#1. Total Sulphur Dioxide and free suphur dioxide are highly corelated to each other,since when Total Sulphur Dioxide ,free suphur dioxide increases too
## Same goes for density and fixed acidity

# %%
sns.scatterplot(x='total sulfur dioxide',y='free sulfur dioxide',data=df)
plt.show()

# %%
sns.scatterplot(x='fixed acidity',y='density',data=df)
# Out:
# <Axes: xlabel='fixed acidity', ylabel='density'>

# %%
## Now we can clearly see these 4 attributes are highly coreeleted to each other

# %%
##Checkimg out liers

# %%
plt.figure(figsize=(20,15))
plotnumber=1
for i in df.columns:
    if plotnumber<=12:
        
        plt.subplot(4,3,plotnumber)
        sns.boxplot(data=df,x=i)
    plotnumber+=1
plt.show()

# %%
df.skew()
# Out:
# fixed acidity           0.982751
# volatile acidity        0.671593
# citric acid             0.318337
# residual sugar          4.540655
# chlorides               5.680347
# free sulfur dioxide     1.250567
# total sulfur dioxide    1.515531
# density                 0.071288
# pH                      0.193683
# sulphates               2.428672
# alcohol                 0.860829
# quality                 0.217802
# dtype: float64

# %%
## We can see this very clearly that Outliers are present in every feature except density and citric acid
## Let us check skewness through distribution of data

# %%
plt.figure(figsize=(20,15))
plotnumber=1
for i in df.columns:
    if plotnumber<=13:
        sns.distplot(x=i)
    pltnumber+=1
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 5
#       3 for i in df.columns:
#       4     if plotnumber<=13:
# ----> 5         sns.distplot(x=i)
#       6     pltnumber+=1
#       7 plt.show()
#
# File ~\anaconda3\lib\site-packages\seaborn\distributions.py:2458, in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax, x)
#    2455     a = x
#    2457 # Make a a 1-d float array
# -> 2458 a = np.asarray(a, float)
#    2459 if a.ndim > 1:
#    2460     a = a.squeeze()
#
# ValueError: could not convert string to float: 'fixed acidity'

# %%
df['fixed acidity']=np.cbrt(df['fixed acidity'])
df['volatile acidity']=np.cbrt(df['volatile acidity'])
df['residual sugar']=np.cbrt(df['residual sugar'])
df['chlorides']=np.cbrt(df['chlorides'])
df['free sulfur dioxide']=np.cbrt(df['free sulfur dioxide'])
df['total sulfur dioxide']=np.cbrt(df['total sulfur dioxide'])
df['pH']=np.cbrt(df['pH'])
df['sulphates']=np.cbrt(df['sulphates'])
df['alcohol']=np.cbrt(df['alcohol'])

# %%
df.shape
# Out:
# (1599, 12)

# %%
df.skew()
# Out:
# fixed acidity           0.401091
# volatile acidity       -0.392904
# citric acid             0.318337
# residual sugar          1.880554
# chlorides               1.895583
# free sulfur dioxide    -0.178132
# total sulfur dioxide   -0.027282
# density                 0.071288
# pH                      0.012025
# sulphates               1.046979
# alcohol                 0.725907
# quality                 0.217802
# dtype: float64

# %%
plt.figure(figsize=(20,11))
plotnumber=1
for i in df:
    if plotnumber<=12:
        ax=plt.subplot(4,3,plotnumber)
        sns.distplot(df[i])
    plotnumber+=1
plt.show()

# %%
# Outliers have been removed still it can be seen some skewness in residual sugar ,chlorides, sulphates and alcohol

# %%
from sklearn.preprocessing import power_transform
df[['residual sugar','chlorides','alcohol','sulphates']]=power_transform(df[['residual sugar','chlorides','alcohol','sulphates']])

# %%
df[['residual sugar','chlorides','alcohol','sulphates']].skew()
# Out:
# residual sugar    0.000000
# chlorides        -0.518733
# alcohol           0.112911
# sulphates        -0.023965
# dtype: float64

# %%
df.skew()
# Out:
# fixed acidity           0.401091
# volatile acidity       -0.392904
# citric acid             0.318337
# residual sugar          0.000000
# chlorides              -0.518733
# free sulfur dioxide    -0.178132
# total sulfur dioxide   -0.027282
# density                 0.071288
# pH                      0.012025
# sulphates              -0.023965
# alcohol                 0.112911
# quality                 0.217802
# dtype: float64

# %%
(df['quality']>7).value_counts()
# Out:
# False    1581
# True       18
# Name: quality, dtype: int64

# %%
(df['quality']<=7).value_counts()
# Out:
# True     1581
# False      18
# Name: quality, dtype: int64

# %%
(df['quality']>7).replace('7',' Good/1')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1594    False
# 1595    False
# 1596    False
# 1597    False
# 1598    False
# Name: quality, Length: 1599, dtype: bool

# %%
(df['quality']>7).replace('8','Good/1')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1594    False
# 1595    False
# 1596    False
# 1597    False
# 1598    False
# Name: quality, Length: 1599, dtype: bool

# %%
df.loc[(df['quality'] < 7.0),'quality']=0.0
df.loc[(df['quality'] >=7.0),'quality']=1

# %%
## After using Zscore for removing outliers rest of the skewness has also been removed

# %%
data=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/DSData/master/winequality-red.csv')
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
## Dividing the data between X and Y

# %%
y=df.quality
x=df.drop('quality',axis=1)

# %%
## Balancing the data

# %% [raw]
# from imblearn.over_sampling import
# SM=SMOTE
# x,y=SM.fit_resample(data,x,y)

# %%
from imblearn.over_sampling import RandomOverSampler
ros=RandomOverSampler(random_state=42)
x_ros,y_ros=ros.fit_resample(x,y)
print('The shape of data target data before oversampling: ',y.shape)
print('The shape of data target data before oversampling: ',y_ros.shape)
# Out:
# The shape of data target data before oversampling:  (1599,)
# The shape of data target data before oversampling:  (2764,)

# %%
x_ros.shape
# Out:
# (2764, 11)

# %%
y_ros.value_counts()
# Out:
# 0    1382
# 1    1382
# Name: quality, dtype: int64

# %%
## Target variable is balanced now

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=56)

# %%
## Classifications algorithms

# %%
from sklearn.ensemble import RandomForestClassifier , ExtraTreesClassifier , GradientBoostingClassifier, AdaBoostClassifier, BaggingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix ,roc_curve, accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
RFC=RandomForestClassifier()
RFC.fit(x_train,y_train)
predRFC=RFC.predict(x_test)
print(accuracy_score(y_test,predRFC))
print(confusion_matrix(y_test,predRFC))
print(classification_report(y_test,predRFC))
# Out:
# 0.9175
# [[345   6]
#  [ 27  22]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95       351
#            1       0.79      0.45      0.57        49
#
#     accuracy                           0.92       400
#    macro avg       0.86      0.72      0.76       400
# weighted avg       0.91      0.92      0.91       400

# %%
print(RFC.score(x_train,y_train))
print(RFC.score(x_test,y_test))
# Out:
# 1.0
# 0.9175

# %%
RFCscore=cross_val_score(RFC,x,y)
print(np.mean(RFCscore))
print('Difference between accuracy and crossv validation score-',accuracy_score(y_test,predRFC)-np.mean(RFCscore))
# Out:
# 0.8717985893416929
# Difference between accuracy and crossv validation score- 0.04570141065830713

# %%
LR=LogisticRegression
LR.fit(x_ros,y_ros,sample_weight=7)
predLR=LR.predict(x_test)
print(accuracy_score(y_test,predLR))
print(confusion_matrix(y_test,predLR))
print(classification_report(y_test,predLR))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[91], line 2
#       1 LR=LogisticRegression
# ----> 2 LR.fit(x_ros,y_ros,sample_weight=7)
#       3 predLR=LR.predict(x_test)
#       4 print(accuracy_score(y_test,predLR))
#
# TypeError: LogisticRegression.fit() missing 1 required positional argument: 'y'

# %%
ET=ExtraTreesClassifier()
ET.fit(x_train,y_train)
predET=ET.predict(x_test)
print(accuracy_score(y_test,predET))
print(confusion_matrix(y_test,predET))
print(classification_report(y_test,predET))
# Out:
# 0.91
# [[342   9]
#  [ 27  22]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       351
#            1       0.71      0.45      0.55        49
#
#     accuracy                           0.91       400
#    macro avg       0.82      0.71      0.75       400
# weighted avg       0.90      0.91      0.90       400

# %%
print(ET.score(x_train,y_train))
print(ET.score(x_test,y_test))
# Out:
# 1.0
# 0.91

# %%
ETscore=cross_val_score(ET,x,y)
print(np.mean(ETscore))
print('Difference between accuracy and cross validation score-',accuracy_score(y_test,predET)-np.mean(ETscore))
# Out:
# 0.8668005485893417
# Difference between accuracy and cross validation score- 0.043199451410658285

# %%
SVC.fit(x_train,y_train)
predsvc=svc.predict(x_test)
print(accuracy_score(y_test,predsvc))
print(classification_report(y_test,predsvc))
print(confusion_matrix(y_test,predsvc))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 SVC.fit(x_train,y_train)
#       2 predsvc=svc.predict(x_test)
#       3 print(accuracy_score(y_test,predsvc))
#
# TypeError: BaseLibSVM.fit() missing 1 required positional argument: 'y'

# %%
ada=AdaBoostClassifier()
ada.fit(x_train,y_train)
predada=ada.predict(x_test)
print(accuracy_score(y_test,predada))
print(classification_report(y_test,predada))
print(confusion_matrix(y_test,predada))
# Out:
# 0.8925
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94       351
#            1       0.58      0.43      0.49        49
#
#     accuracy                           0.89       400
#    macro avg       0.75      0.69      0.72       400
# weighted avg       0.88      0.89      0.89       400
#
# [[336  15]
#  [ 28  21]]

# %%
print(ada.score(x_train,y_train))
print(ada.score(x_test,y_test))
# Out:
# 0.9057547956630525
# 0.8925

# %%
adascore=cross_val_score(ada,x,y)
print(np.mean(adascore))
print('Difference between accuracy and cross validation score-',accuracy_score(y_test,predada)-np.mean(adascore))
# Out:
# 0.8574137931034482
# Difference between accuracy and cross validation score- 0.03508620689655173

# %%
gbc=GradientBoostingClassifier()
gbc.fit(x_train,y_train)
predgbc=gbc.predict(x_test)
print(accuracy_score(y_test,predgbc))
print(confusion_matrix(y_test,predgbc))
print(classification_report(y_test,predgbc))
# Out:
# 0.925
# [[343   8]
#  [ 22  27]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96       351
#            1       0.77      0.55      0.64        49
#
#     accuracy                           0.93       400
#    macro avg       0.86      0.76      0.80       400
# weighted avg       0.92      0.93      0.92       400

# %%
print(gbc.score(x_train,y_train))
print(gbc.score(x_test,y_test))
# Out:
# 0.9624687239366139
# 0.925

# %%
gbcscore=cross_val_score(gbc,x,y)
print(np.mean(gbcscore))
print('Difference between accuracy and cross validation score-',accuracy_score(y_test,predgbc)-np.mean(gbcscore))
# Out:
# 0.865546630094044
# Difference between accuracy and cross validation score- 0.059453369905956066

# %%
bc=BaggingClassifier()
bc.fit(x_train,y_train)
bcpred=bc.predict(x_test)
print(accuracy_score(y_test,bcpred))
print(classification_report(y_test,bcpred))
print(confusion_matrix(y_test,bcpred))
# Out:
# 0.8925
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94       351
#            1       0.62      0.31      0.41        49
#
#     accuracy                           0.89       400
#    macro avg       0.77      0.64      0.68       400
# weighted avg       0.87      0.89      0.88       400
#
# [[342   9]
#  [ 34  15]]

# %%
print(bc.score(x_train,y_train))
print(bc.score(x_test,y_test))
# Out:
# 0.9924937447873228
# 0.8925

# %%
bcscore=cross_val_score(bc,x,y)
print(np.mean(bcscore))
print('Difference between accuracy and cross validation score-',accuracy_score(y_test,bcpred)-np.mean(bcscore))
# Out:
# 0.8711657523510972
# Difference between accuracy and cross validation score- 0.021334247648902793

# %%
knn=KNeighborsClassifier()
knn.fit(x_train,y_train)
knnpre=knn.predict(x_test)
print(accuracy_score(y_test,knnpre))
print(classification_report(y_test,knnpre))
print(confusion_matrix(y_test,knnpre))
# Out:
# 0.8725
#               precision    recall  f1-score   support
#
#            0       0.90      0.96      0.93       351
#            1       0.46      0.27      0.34        49
#
#     accuracy                           0.87       400
#    macro avg       0.68      0.61      0.63       400
# weighted avg       0.85      0.87      0.86       400
#
# [[336  15]
#  [ 36  13]]

# %%
print(knn.score(x_train,y_train))
print(knn.score(x_test,y_test))
# Out:
# 0.8924103419516264
# 0.8725

# %%
knnscore=cross_val_score(knn,x,y)
print(np.mean(knnscore))
print('Difference between accuracy and cross validation score-',accuracy_score(y_test,knnpre)-np.mean(knnscore))
# Out:
# 0.8449235893416928
# Difference between accuracy and cross validation score- 0.027576410658307293

# %%
dtc=DecisionTreeClassifier()
dtc.fit(x_train,y_train)
dtcpre=dtc.predict(x_test)
print(accuracy_score(y_test,dtcpre))
print(classification_report(y_test,dtcpre))
print(confusion_matrix(y_test,dtcpre))
# Out:
# 0.875
#               precision    recall  f1-score   support
#
#            0       0.92      0.93      0.93       351
#            1       0.49      0.45      0.47        49
#
#     accuracy                           0.88       400
#    macro avg       0.71      0.69      0.70       400
# weighted avg       0.87      0.88      0.87       400
#
# [[328  23]
#  [ 27  22]]

# %%
print(dtc.score(x_train,y_train))
print(dtc.score(x_test,y_test))
# Out:
# 1.0
# 0.875

# %%
dtcscore=cross_val_score(dtc,x,y)
print(np.mean(dtcscore))
print('Difference between accuracy and cross validation score-',accuracy_score(y_test,dtcpre)-np.mean(dtcscore))
# Out:
# 0.8061167711598747
# Difference between accuracy and cross validation score- 0.06888322884012532

# %%
## Bagging classifier model has the least difference between Accuracy score and cross validation score
## Hence we'll go ahead for Hyperparameter tuning with GradientBoostingClassifier

# %%
### Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
GradientBoostingClassifier()
param_grid={'max_features':[19], 'n_estimators':[300]}

# %%
bgc_grid=GridSearchCV(GradientBoostingClassifier(),param_grid,n_jobs=-1,cv=11,verbose=2)

# %%
bgc_grid.fit(x_train,y_train)
# Out:
# Fitting 11 folds for each of 1 candidates, totalling 11 fits
# GridSearchCV(cv=11, estimator=GradientBoostingClassifier(), n_jobs=-1,
#              param_grid={'max_features': [19], 'n_estimators': [300]},
#              verbose=2)

# %%
bgc_pred=bgc_grid.predict(x_test)
print(accuracy_score(y_test,bgc_pred))
# Out:
# 0.92

# %%
## As we can see the accuracy increased after Hyperparameter tuning

# %% [markdown]
# ### Saving the Model

# %%
import joblib
joblib.dump(bgc_grid.best_estimator_,'Red wine quality project')
# Out:
# ['Red wine quality project']
